# %% [markdown]
# # Chapter 7 Moving Beyond Linearity

# %% [markdown]
# ## 7.8 Lab: Non-Linear Modeling pp 310

# %%
# As usual, we start with some of our standard imports.
import numpy as np, pandas as pd
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from ISLP import load_data
from ISLP.models import (summarize ,
                         poly ,
                         ModelSpec as MS)
from statsmodels.stats.anova import anova_lm

# %%
# collect the new imports needed for this lab. Many of these are developed specifically for the ISLP package.
from pygam import (s as s_gam ,
                   l as l_gam,
                   f as f_gam,
                   LinearGAM ,
                   LogisticGAM)
from ISLP.transforms import (BSpline ,
                             NaturalSpline)
from ISLP.models import bs, ns
from ISLP.pygam import (approx_lam ,
                        degrees_of_freedom ,
                        plot as plot_gam ,
                        anova as anova_gam)

# %% [markdown]
# ### 7.8.1 Polynomial Regression and Step Functions

# %% [markdown]
# ### 7.8.2 Splines

# %% [markdown]
# ### 7.8.3 Smoothing Splines and GAMs

# %% [markdown]
# ### 7.8.4 Local Regression
