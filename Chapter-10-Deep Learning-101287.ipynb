# %% [markdown]
# # Chapter-10-Deep Learning-101287

# %% [markdown]
# ## 10.9 Lab: Deep Learning

# %%
# We start with several standard imports that we have seen before.
import numpy as np, pandas as pd
from matplotlib.pyplot import subplots
from sklearn.linear_model import \
     (LinearRegression ,
     LogisticRegression ,
     Lasso)
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from ISLP import load_data
from ISLP.models import ModelSpec as MS
from sklearn.model_selection import \
     (train_test_split ,
      GridSearchCV)

# %% [markdown]
# ### Torch-Specific Imports

# %%
import torch
from torch import nn
from torch.optim import RMSprop
from torch.utils.data import TensorDataset

# %%
# There are several other helper packages for torch.
from torchmetrics import (MeanAbsoluteError ,
                          R2Score)
from torchinfo import summary
from torchvision.io import read_image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 4
#       1 # There are several other helper packages for torch.
#       2 from torchmetrics import (MeanAbsoluteError ,
#       3                           R2Score)
# ----> 4 from torchinfo import summary
#       5 from torchvision.io import read_image
#
# ModuleNotFoundError: No module named 'torchinfo'
